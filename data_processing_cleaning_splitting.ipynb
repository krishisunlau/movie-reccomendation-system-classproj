# %%
import pandas as pd

movies_df = pd.read_csv('movies.csv')
ratings_df = pd.read_csv('ratings.csv')

# %%
print('movies: ', movies_df.shape, 'data: ', len(movies_df))
print('ratings: ', ratings_df.shape, 'data: ', len(ratings_df))
# Out:
# movies:  (9742, 3) data:  9742
# ratings:  (100836, 4) data:  100836

# %%
movies_df.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
ratings_df.head(10)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# 5       1       70     3.0  964982400
# 6       1      101     5.0  964980868
# 7       1      110     4.0  964982176
# 8       1      151     5.0  964984041
# 9       1      157     5.0  964984100

# %%
# cleaning movies df
movies_df['genres'] = movies_df['genres'].str.split('|')
movies_df['genres'] = movies_df['genres'].apply(lambda d: d if isinstance(d, list) else [])
movies_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                               genres
# 0  [Adventure, Animation, Children, Comedy, Fantasy]
# 1                     [Adventure, Children, Fantasy]
# 2                                  [Comedy, Romance]
# 3                           [Comedy, Drama, Romance]
# 4                                           [Comedy]

# %%
movies_df.to_csv('clean_movies.csv', index=False)
files.download('clean_movies.csv')

# %%
import re

df = pd.merge(ratings_df, movies_df, on='movieId' , how='left')
df['title'] = df['title'].apply(lambda x: re.sub(r'\(\d{4}\)', '', x).strip())
df['genres'] = df['genres'].str.split('|')
df.head(10)
# Out:
#    userId  movieId  rating  timestamp                 title  \
# 0       1        1     4.0  964982703             Toy Story
# 1       1        3     4.0  964981247      Grumpier Old Men
# 2       1        6     4.0  964982224                  Heat
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en)
# 4       1       50     5.0  964982931   Usual Suspects, The
# 5       1       70     3.0  964982400   From Dusk Till Dawn
# 6       1      101     5.0  964980868         Bottle Rocket
# 7       1      110     4.0  964982176            Braveheart
# 8       1      151     5.0  964984041               Rob Roy
# 9       1      157     5.0  964984100        Canadian Bacon
#
#                                               genres
# 0  [Adventure, Animation, Children, Comedy, Fantasy]
# 1                                  [Comedy, Romance]
# 2                          [Action, Crime, Thriller]
# 3                                [Mystery, Thriller]
# ...

# %%
#split data 80-20
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(df, test_size=0.2, stratify=df.userId)

print(f'Training dataset size: {len(train_data)}')
print(f'Testing dataset size: {len(test_data)}')
# Out:
# Training dataset size: 80668
# Testing dataset size: 20168

# %%
test_data = test_data.sort_values(['userId','movieId'])
test_data.head()
# Out:
#     userId  movieId  rating  timestamp                title  \
# 5        1       70     3.0  964982400  From Dusk Till Dawn
# 11       1      216     5.0  964981208        Billy Madison
# 20       1      356     4.0  964980962         Forrest Gump
# 22       1      367     4.0  964981710            Mask, The
# 23       1      423     3.0  964982363           Blown Away
#
#                                 genres
# 5   [Action, Comedy, Horror, Thriller]
# 11                            [Comedy]
# 20       [Comedy, Drama, Romance, War]
# 22    [Action, Comedy, Crime, Fantasy]
# 23                  [Action, Thriller]

# %%
train_data = train_data.sort_values(['userId', 'movieId'])
train_data.head()
# Out:
#    userId  movieId  rating  timestamp                 title  \
# 0       1        1     4.0  964982703             Toy Story
# 1       1        3     4.0  964981247      Grumpier Old Men
# 2       1        6     4.0  964982224                  Heat
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en)
# 4       1       50     5.0  964982931   Usual Suspects, The
#
#                                               genres
# 0  [Adventure, Animation, Children, Comedy, Fantasy]
# 1                                  [Comedy, Romance]
# 2                          [Action, Crime, Thriller]
# 3                                [Mystery, Thriller]
# 4                         [Crime, Mystery, Thriller]

# %%
train_data.to_csv('training_data.csv', index = False)
test_data.to_csv('testing_data.csv', index = False)
